# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report , mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.decomposition import PCA

# %%
train_data = pd.read_csv('../Desktop/anaconda3/train.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
one_hot_encoder = OneHotEncoder()

# %%
train_data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train_data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train_data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.fillna(value = RandomForestRegressor , inplace = True)

# %%
train_data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_data['Embarked'].value_counts()
# Out:
# S                                                           644
# C                                                           168
# Q                                                            77
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>      2
# Name: Embarked, dtype: int64

# %%
train_data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 820          821         1       1
# 615          616         1       2
# 635          636         1       2
# 451          452         0       3
# 650          651         0       3
# 16            17         0       3
# 613          614         0       3
# 269          270         1       1
# 444          445         1       3
# 172          173         1       3
#
#                                                   Name     Sex  \
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female
# 615                                Herman, Miss. Alice  female
# 635                                  Davis, Miss. Mary  female
# 451                    Hagland, Mr. Ingvald Olai Olsen    male
# 650                                  Mitkoff, Mr. Mito    male
# 16                                Rice, Master. Eugene    male
# 613                                   Horgan, Mr. John    male
# 269                             Bissette, Miss. Amelia  female
# 444                  Johannesen-Bratthammer, Mr. Bernt    male
# 172                       Johnson, Miss. Eleanor Ileen  female
#
#                                                    Age  SibSp  Parch  \
# 820                                               52.0      1      1
# 615                                               24.0      1      2
# 635                                               28.0      0      0
# 451  <class 'sklearn.ensemble._forest.RandomForestR...      1      0
# 650  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 16                                                 2.0      4      1
# 613  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 269                                               35.0      0      0
# 444  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 172                                                1.0      1      1
#
#        Ticket      Fare                                              Cabin  \
# 820     12749   93.5000                                                B69
# 615    220845   65.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 635    237668   13.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 451     65303   19.9667  <class 'sklearn.ensemble._forest.RandomForestR...
# 650    349221    7.8958  <class 'sklearn.ensemble._forest.RandomForestR...
# 16     382652   29.1250  <class 'sklearn.ensemble._forest.RandomForestR...
# 613    370377    7.7500  <class 'sklearn.ensemble._forest.RandomForestR...
# 269  PC 17760  135.6333                                                C99
# 444     65306    8.1125  <class 'sklearn.ensemble._forest.RandomForestR...
# 172    347742   11.1333  <class 'sklearn.ensemble._forest.RandomForestR...
#
#     Embarked
# 820        S
# 615        S
# 635        S
# 451        S
# 650        S
# 16         Q
# 613        Q
# 269        S
# 444        S
# 172        S

# %%
mapper = {
    'male' : 0 ,
    'female' :1
}

train_data['Sex'] = train_data['Sex'].map(mapper)

# %%
train_data['Sex'].unique()
# Out:
# array([0, 1])

# %%
mapper_embarked = {
    'S' : 0,
    'C' : 1,
    'Q' : 2,
}

train_data['Embarked'] = train_data['Embarked'].map(mapper_embarked)

# %%
train_data['Embarked'].unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
train_data['Cabin'].value_counts()
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>    687
# C23 C25 C27                                                   4
# G6                                                            4
# B96 B98                                                       4
# C22 C26                                                       3
#                                                            ...
# E34                                                           1
# C7                                                            1
# C54                                                           1
# E36                                                           1
# C148                                                          1
# Name: Cabin, Length: 148, dtype: int64

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass                             Name  Sex  \
# 333          334         0       3  Vander Planke, Mr. Leo Edmondus    0
# 145          146         0       2     Nicholls, Mr. Joseph Charles    0
# 484          485         1       1          Bishop, Mr. Dickinson H    0
# 286          287         1       3          de Mulder, Mr. Theodore    0
# 134          135         0       2   Sobey, Mr. Samuel James Hayden    0
# 107          108         1       3           Moss, Mr. Albert Johan    0
# 336          337         0       1        Pears, Mr. Thomas Clinton    0
# 233          234         1       3   Asplund, Miss. Lillian Gertrud    1
# 674          675         0       2       Watson, Mr. Ennis Hastings    0
# 90            91         0       3             Christmann, Mr. Emil    0
#
#                                                    Age  SibSp  Parch  \
# 333                                               16.0      2      0
# 145                                               19.0      1      1
# 484                                               25.0      1      0
# 286                                               30.0      0      0
# 134                                               25.0      0      0
# 107  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 336                                               29.0      1      0
# 233                                                5.0      4      2
# 674  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 90                                                29.0      0      0
#
#          Ticket     Fare                                              Cabin  \
# 333      345764  18.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 145  C.A. 33112  36.7500  <class 'sklearn.ensemble._forest.RandomForestR...
# 484       11967  91.0792                                                B49
# 286      345774   9.5000  <class 'sklearn.ensemble._forest.RandomForestR...
# 134  C.A. 29178  13.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 107      312991   7.7750  <class 'sklearn.ensemble._forest.RandomForestR...
# 336      113776  66.6000                                                 C2
# 233      347077  31.3875  <class 'sklearn.ensemble._forest.RandomForestR...
# 674      239856   0.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 90       343276   8.0500  <class 'sklearn.ensemble._forest.RandomForestR...
#
#      Embarked
# 333       0.0
# 145       0.0
# 484       1.0
# 286       0.0
# 134       0.0
# 107       0.0
# 336       0.0
# 233       0.0
# 674       0.0
# 90        0.0

# %%
train_data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
train_data['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 633          634         0       1
# 655          656         0       2
# 748          749         0       1
# 839          840         1       1
# 315          316         1       3
# 366          367         1       1
# 804          805         1       3
# 253          254         0       3
# 819          820         0       3
# 330          331         1       3
#
#                                                  Name  Sex  \
# 633                     Parr, Mr. William Henry Marsh    0
# 655                         Hickman, Mr. Leonard Mark    0
# 748                         Marvin, Mr. Daniel Warner    0
# 839                              Marechal, Mr. Pierre    0
# 315                   Nilsson, Miss. Helmina Josefina    1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)    1
# 804                           Hedman, Mr. Oskar Arvid    0
# 253                          Lobb, Mr. William Arthur    0
# 819                      Skoog, Master. Karl Thorsten    0
# 330                                McCoy, Miss. Agnes    1
#
#                                                    Age  SibSp  Parch  \
# 633  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 655                                               24.0      2      0
# 748                                               19.0      1      0
# 839  <class 'sklearn.ensemble._forest.RandomForestR...      0      0
# 315                                               26.0      0      0
# 366                                               60.0      1      0
# 804                                               27.0      0      0
# 253                                               30.0      1      0
# 819                                               10.0      3      2
# 330  <class 'sklearn.ensemble._forest.RandomForestR...      2      0
#
#            Ticket     Fare                                              Cabin  \
# 633        112052   0.0000  <class 'sklearn.ensemble._forest.RandomForestR...
# 655  S.O.C. 14879  73.5000  <class 'sklearn.ensemble._forest.RandomForestR...
# 748        113773  53.1000                                                D30
# 839         11774  29.7000                                                C47
# 315        347470   7.8542  <class 'sklearn.ensemble._forest.RandomForestR...
# 366        110813  75.2500                                                D37
# 804        347089   6.9750  <class 'sklearn.ensemble._forest.RandomForestR...
# 253     A/5. 3336  16.1000  <class 'sklearn.ensemble._forest.RandomForestR...
# 819        347088  27.9000  <class 'sklearn.ensemble._forest.RandomForestR...
# 330        367226  23.2500  <class 'sklearn.ensemble._forest.RandomForestR...
#
#      Embarked
# 633       0.0
# 655       0.0
# 748       0.0
# 839       1.0
# 315       0.0
# 366       1.0
# 804       0.0
# 253       0.0
# 819       0.0
# 330       2.0

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.drop(['PassengerId' , 'Name' , 'Ticket' , 'Cabin'] ,axis = 1 , inplace = True)

# %%
y = train_data['Survived']
x = train_data.drop(['Survived'] , axis = 1)

# %%
x[:5]
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    0  22.0      1      0   7.2500       0.0
# 1       1    1  38.0      1      0  71.2833       1.0
# 2       3    1  26.0      0      0   7.9250       0.0
# 3       1    1  35.0      1      0  53.1000       0.0
# 4       3    0  35.0      0      0   8.0500       0.0

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y ,
                                                      test_size = 0.2)

# %%
x_train[:5]
# Out:
#      Pclass  Sex                                                Age  SibSp  \
# 825       3    0  <class 'sklearn.ensemble._forest.RandomForestR...      0
# 234       2    0                                               24.0      0
# 77        3    0  <class 'sklearn.ensemble._forest.RandomForestR...      0
# 605       3    0                                               36.0      1
# 47        3    1  <class 'sklearn.ensemble._forest.RandomForestR...      0
#
#      Parch   Fare  Embarked
# 825      0   6.95       2.0
# 234      0  10.50       0.0
# 77       0   8.05       0.0
# 605      0  15.55       0.0
# 47       0   7.75       2.0

# %%
dtree = DecisionTreeRegressor()
rand_forest = RandomForestRegressor()
knn = KNeighborsRegressor(n_neighbors = 7 , n_jobs = -1)

# %%
x_train
# Out:
#      Pclass  Sex                                                Age  SibSp  \
# 825       3    0  <class 'sklearn.ensemble._forest.RandomForestR...      0
# 234       2    0                                               24.0      0
# 77        3    0  <class 'sklearn.ensemble._forest.RandomForestR...      0
# 605       3    0                                               36.0      1
# 47        3    1  <class 'sklearn.ensemble._forest.RandomForestR...      0
# ..      ...  ...                                                ...    ...
# 593       3    1  <class 'sklearn.ensemble._forest.RandomForestR...      0
# 407       2    0                                                3.0      1
# 37        3    0                                               21.0      0
# 297       1    1                                                2.0      1
# 29        3    0  <class 'sklearn.ensemble._forest.RandomForestR...      0
#
#      Parch      Fare  Embarked
# 825      0    6.9500       2.0
# 234      0   10.5000       0.0
# 77       0    8.0500       0.0
# 605      0   15.5500       0.0
# 47       0    7.7500       2.0
# ..     ...       ...       ...
# 593      2    7.7500       2.0
# 407      1   18.7500       0.0
# 37       0    8.0500       0.0
# 297      2  151.5500       0.0
# 29       0    7.8958       0.0
#
# [712 rows x 7 columns]

# %%
dtree.fit(x_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dtree.fit(x_train , y_train)
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:242, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     238 check_X_params = dict(
#     239     dtype=DTYPE, accept_sparse="csc", force_all_finite=False
#     240 )
#     241 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 242 X, y = self._validate_data(
#     243     X, y, validate_separately=(check_X_params, check_y_params)
#     244 )
#     246 missing_values_in_feature_mask = (
#     247     self._compute_missing_values_in_feature_mask(X)
#     248 )
#     249 if issparse(X):
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/base.py:616, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     614 if "estimator" not in check_X_params:
#     615     check_X_params = {**default_check_params, **check_X_params}
# --> 616 X = check_array(X, input_name="X", **check_X_params)
#     617 if "estimator" not in check_y_params:
#     618     check_y_params = {**default_check_params, **check_y_params}
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         array = xp.astype(array, dtype, copy=False)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#     919     raise ValueError(
#     920         "Complex data not supported\n{}\n".format(array)
#     921     ) from complex_warning
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File ~/Desktop/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# TypeError: float() argument must be a string or a real number, not 'ABCMeta'

# %%
rand_forest.fit(x_train , y_train)

# %%
    train_data[train_data['Survived'] == 'ABCMeta']
